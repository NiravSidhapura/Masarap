# %%
import pandas as pd

# %%
df_1=pd.read_csv(r"e:\project\articles.csv")

# %%
df_1.shape
# Out:
# (105542, 25)

# %%
df_1.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# ...

# %%
df_2=pd.read_csv(r"e:\project\transactions_train.csv")

# %%
df_2.head()
df_2.shape
# Out:
# (31788324, 5)

# %%
df_2.tail()
# Out:
#                t_dat                                        customer_id  \
# 31788319  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788320  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788321  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 31788322  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 31788323  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#           article_id     price  sales_channel_id
# 31788319   929511001  0.059305                 2
# 31788320   891322004  0.042356                 2
# 31788321   918325001  0.043203                 1
# 31788322   833459002  0.006763                 1
# 31788323   898573003  0.033881                 2

# %%
def_merged=df_2.merge(df_1,on='article_id')

# %%
def_merged.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  3681748607f3287d2c3a65e00bb5fb153de30e9becf158...   663713001
# 2  2018-09-20  4ef5967ff17bf474bffebe5b16bd54878e1d4105f7b4ed...   663713001
# 3  2018-09-20  6b7b10d2d47516c82a6f97332478dab748070f09693f09...   663713001
# 4  2018-09-20  8ac137752bbe914aa4ae6ad007a9a0c5b67a1ab2b2d474...   663713001
#
#       price  sales_channel_id  product_code                 prod_name  \
# 0  0.050831                 2        663713  Atlanta Push Body Harlow
# 1  0.049475                 2        663713  Atlanta Push Body Harlow
# 2  0.050831                 2        663713  Atlanta Push Body Harlow
# 3  0.050831                 1        663713  Atlanta Push Body Harlow
# 4  0.050831                 2        663713  Atlanta Push Body Harlow
#
#    product_type_no product_type_name product_group_name  ...  \
# ...

# %%
def_merged['product_code'].isnull().sum()
# Out:
# 0

# %%
def_merged.columns
# Out:
# Index(['t_dat', 'customer_id', 'article_id', 'price', 'sales_channel_id',
#        'product_code', 'prod_name', 'product_type_no', 'product_type_name',
#        'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'colour_group_code', 'colour_group_name',
#        'perceived_colour_value_id', 'perceived_colour_value_name',
#        'perceived_colour_master_id', 'perceived_colour_master_name',
#        'department_no', 'department_name', 'index_code', 'index_name',
#        'index_group_no', 'index_group_name', 'section_no', 'section_name',
#        'garment_group_no', 'garment_group_name', 'detail_desc'],
#       dtype='object')

# %%
columns_to_keep = ['t_dat', 'article_id', 'price', 'product_group_name', 'product_code','product_type_no']

# Drop columns not in the 'columns_to_keep' list
columns_to_drop = [col for col in def_merged.columns if col not in columns_to_keep]
filtered_df = def_merged.drop(columns=columns_to_drop)

# %%
filtered_df.columns
# Out:
# Index(['t_dat', 'article_id', 'price', 'product_code', 'product_type_no',
#        'product_group_name'],
#       dtype='object')

# %%
filtered_df.head()
# Out:
#         t_dat  article_id     price  product_code  product_type_no  \
# 0  2018-09-20   663713001  0.050831        663713              283
# 1  2018-09-20   663713001  0.049475        663713              283
# 2  2018-09-20   663713001  0.050831        663713              283
# 3  2018-09-20   663713001  0.050831        663713              283
# 4  2018-09-20   663713001  0.050831        663713              283
#
#   product_group_name
# 0          Underwear
# 1          Underwear
# 2          Underwear
# 3          Underwear
# 4          Underwear

# %%
filtered_df['price'].isnull().sum()
# Out:
# 0

# %%
filtered_df.shape
# Out:
# (31788324, 6)

# %%
filtered_df.tail()
# Out:
#                t_dat  article_id     price  product_code  product_type_no  \
# 31788319  2020-09-22   860135008  0.038119        860135              259
# 31788320  2020-09-22   539060028  0.016017        539060              308
# 31788321  2020-09-22   539060028  0.016000        539060              308
# 31788322  2020-09-22   810737015  0.033881        810737               49
# 31788323  2020-09-22   533261032  0.033881        533261              256
#
#            product_group_name
# 31788319   Garment Upper body
# 31788320   Garment Upper body
# 31788321   Garment Upper body
# 31788322  Underwear/nightwear
# 31788323   Garment Upper body

# %%
filtered_df.to_csv('Actual_data_cdac.csv',index=False)

# %%
#filtered_df['quantity_sold'] = filtered_df.groupby(['t_dat', 'product_group_name'])['quantity_column_name'].transform('sum')
""" grouped = filtered_df.groupby(['t_dat', 'product_group_name']).size().reset_index(name='quantity_sold')

# Merge the grouped data back to the original DataFrame
filtered_df = pd.merge(filtered_df, grouped, on=['t_dat', 'product_group_name'], how='left')

# Print the updated DataFrame
print(filtered_df)
 """
# Out:
# " grouped = filtered_df.groupby(['t_dat', 'product_group_name']).size().reset_index(name='quantity_sold')\n\n# Merge the grouped data back to the original DataFrame\nfiltered_df = pd.merge(filtered_df, grouped, on=['t_dat', 'product_group_name'], how='left')\n\n# Print the updated DataFrame\nprint(filtered_df)\n "

# %%
# Group by 't_dat' and 'product_group_name', then calculate sum of quantities
grouped = filtered_df.groupby(['t_dat', 'product_group_name']).sum().reset_index()

# Merge the grouped data back to the original DataFrame
filtered_df = pd.merge(filtered_df, grouped, on=['t_dat', 'product_group_name'], how='left')

# Rename the newly created column


# Print the updated DataFrame
print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\Aatif\Merging_only_importat_columns.ipynb Cell 20 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Aatif/Merging_only_importat_columns.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> # Group by 't_dat' and 'product_group_name', then calculate sum of quantities
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aatif/Merging_only_importat_columns.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> grouped = filtered_df.groupby(['t_dat', 'product_group_name']).sum().reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/Aatif/Merging_only_importat_columns.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> # Merge the grouped data back to the original DataFrame
# ...
